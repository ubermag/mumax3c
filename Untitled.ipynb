# %%
import mumax3c as mc

# %%
import micromagneticmodel as mm

# %%
system = mm.examples.macrospin()

# %%
md = mc.MinDriver()
md.drive(system, save=True, overwrite=True)
# Out:
# {}
# Running mumax3 (ExeMumax3Runner) [2020/03/13 16:40]... (0.3 s)

# %%
system.m.average
# Out:
# (0.0, 3.564304705455982e-29, 1000000.0)

# %%
td = mc.TimeDriver()
td.drive(system, t=1e-9, n=10, save=True)
# Out:
# {}
# Running mumax3 (ExeMumax3Runner) [2020/03/13 16:40]... (0.3 s)

# %%
import discretisedfield as df

mesh = df.Mesh(p1=(-20e-9, -20e-9, 0), p2=(20e-9, 20e-9, 5e-9), n=(20, 20, 5))
system = mm.System(name='mag')
system.energy = mm.Zeeman(H=(0, 0, 1e6))
system.dynamics = mm.Precession(gamma0=mm.consts.gamma0) + mm.Damping(alpha=1)

def Ms_fun(pos):
    x, y, z = pos
    if x**2 + y**2 < (20e-9)**2:
        return 1e6
    else:
        return 0

system.m = df.Field(mesh, dim=3, value=(0, 1, 1), norm=Ms_fun)

# %%
#md.drive(system, save=True, overwrite=True)
td.drive(system, t=1e-9, n=10, save=True, overwrite=True)
# Out:
# {}
# Running mumax3 (ExeMumax3Runner) [2020/03/13 16:40]... (0.3 s)

# %%
system.m
# Out:
# Field(mesh=Mesh(region=Region(p1=(-2e-08, -2e-08, 0.0), p2=(2e-08, 2e-08, 5e-09)), n=(20, 20, 5), pbc=set(), subregions={}), dim=3)

# %%
system.m.plane('z').mpl()

# %%
system.m.average
# Out:
# (-0.7897326362133026, 2.4115155029296873, 790000.0)

# %%
md.drive(system)
# Out:
# {}
# Running mumax3 (ExeMumax3Runner) [2020/03/13 16:40]... (0.2 s)

# %%
system.m.average
# Out:
# (-2.147409811068916e-26, 3.4196506932791934e-26, 790000.0)

# %%
df.__name__
# Out:
# 'discretisedfield'

# %%
import numpy as np
import random

name = 'tst'

p1 = (-10e-9, -5e-9, -3e-9)
p2 = (10e-9, 5e-9, 3e-9)
region = df.Region(p1=p1, p2=p2)
cell = (2e-9, 2e-9, 2e-9)

system = mm.System(name=name)
system.energy = mm.Exchange(A=1e-12)

def rnd(pos):
    return [2*random.random()-1 for i in range(3)]

mesh = df.Mesh(region=region, cell=cell)
system.m = df.Field(mesh, dim=3, value=rnd, norm=1e6)

system.dynamics =  mm.Precession(gamma0=0) + mm.Damping(alpha=1)
td = mc.TimeDriver()
#td.drive(system, t=10e-9, n=10, save=True, overwrite=True)
print(system.m.average)
md.drive(system, save=True, overwrite=True)
print(system.m.average)

value = system.m(mesh.region.centre)
print(value)
assert np.linalg.norm(np.subtract(value, (0, 0, 1e6))) < 1e-3
# Out:
# (-13570.548766290645, -55536.52729919448, 47259.09346835213)
# {}
# Running mumax3 (ExeMumax3Runner) [2020/03/13 16:40]... (0.2 s)
# (-0.00875, 0.0525, -0.066875)
# (-745795.4375, -580824.125, -326240.125)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-4b178e1550ac> in <module>
#      27 value = system.m(mesh.region.centre)
#      28 print(value)
# ---> 29 assert np.linalg.norm(np.subtract(value, (0, 0, 1e6))) < 1e-3
#
# AssertionError:

# %%
system.m.plane('z').mpl()

# %%
print(abs(np.linalg.norm(system.m.average)))

# %%
name = 'exchange_dict'

p1 = (-5e-9, -5e-9, -3e-9)
p2 = (5e-9, 5e-9, 3e-9)
region = df.Region(p1=p1, p2=p2)
n = (10, 10, 6)
subregions = {'r1': df.Region(p1=(-5e-9, -5e-9, -3e-9),
                                   p2=(5e-9, 0, 3e-9)),
                   'r2': df.Region(p1=(-5e-9, 0, -3e-9),
                                   p2=(5e-9, 5e-9, 3e-9))}
        
A = {'r1': 0, 'r2': 1e-12}
Ms = 1e6

system = mm.System(name=name)
system.energy = mm.Exchange(A=A)

mesh = df.Mesh(region=region, n=n,
               subregions=subregions)
system.m = df.Field(mesh, dim=3, value=rnd, norm=Ms)

md.drive(system, save=True, overwrite=True)

# A=0 region
value1 = system.m((1e-9, -4e-9, 2e-9))
value2 = system.m((1e-9, -2e-9, 2e-9))
assert np.linalg.norm(np.subtract(value1, value2)) > 1

# A!=0 region
value1 = system.m((1e-9, 4e-9, 2e-9))
value2 = system.m((1e-9, 2e-9, 2e-9))
assert np.linalg.norm(np.subtract(value1, value2)) < 1
# Out:
# {'r1': 0, 'r2': 1}
# Running mumax3 (ExeMumax3Runner) [2020/03/13 16:40]... (0.2 s)

# %%
system.m.plane('x').mpl()
